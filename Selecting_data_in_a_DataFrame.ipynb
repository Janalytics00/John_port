# %% [markdown]
# <a href="https://colab.research.google.com/github/Janalytics00/John_port/blob/main/Selecting_data_in_a_DataFrame.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Problem 1: Create a dataframe to display the result as below:

# %%
# i'll import pandas library

import pandas as pd

# %%
# writing the code
a = {'Student':['David','Samuel','Terry', 'Evan'],
     'Age':['27', '24', '22', '32'],
     'Country':['UK', 'Canada', 'China', 'USA'],
     'Course':['Python','Data Structure','Machine Learning','Web Development'],
     'Marks':['85','72','89','79']}
df1 = pd.DataFrame(a)
df1
# Out:
#   Student Age Country            Course Marks
# 0   David  27      UK            Python    85
# 1  Samuel  24  Canada    Data Structure    72
# 2   Terry  22   China  Machine Learning    89
# 3    Evan  32     USA   Web Development    79

# %% [markdown]
# Problem 2: Retrieve the Marks column and assign it to a variable b

# %%
b = df1[['Marks']]
b
# Out:
#   Marks
# 0    85
# 1    72
# 2    89
# 3    79

# %% [markdown]
# Problem 3: Retrieve the Country and Course columns and assign it to a variable c

# %%
c = df1[['Country', 'Course']]
c
# Out:
#   Country            Course
# 0      UK            Python
# 1  Canada    Data Structure
# 2   China  Machine Learning
# 3     USA   Web Development

# %% [markdown]
# Problem 3: Retrieve the Country and Course columns and assign it to a variable c

# %% [markdown]
# To view the column as a series, just use one bracket:

# %%
# Get the Student column as a series Object

x = df1['Student']
x
# Out:
# 0     David
# 1    Samuel
# 2     Terry
# 3      Evan
# Name: Student, dtype: object

# %%
#check the type of x
type(x)
# Out:
# pandas.core.series.Series

# %% [markdown]
# Exercise 2: loc() and iloc() functions

# %% [markdown]
# loc() is a label-based data selecting method which means that we have to pass the name of the row or column that we want to select. This method includes the last element of the range passed in it.
#
#
# Simple syntax for your understanding:
#
# loc[row_label, column_label]
#
#
# iloc() is an indexed-based selecting method which means that we have to pass an integer index in the method to select a specific row/column. This method does not include the last element of the range passed in it.
#
#
# Simple syntax for your understanding:
#
# iloc[row_index, column_index]

# %%
# Access the value on the first row and the first column

df1.iloc[0, 0]
# Out:
# 'David'

# %%
# Access the value on the first row and the third column

df1.iloc[0,2]
# Out:
# 'UK'

# %% [markdown]
# Exercise 3: Slicing
#
# Slicing uses the [] operator to select a set of rows and/or columns from a DataFrame.
#
# To slice out a set of rows, you use this syntax: data[start:stop],

# %%
df1.iloc[0:3]
# Out:
#   Student Age Country            Course Marks
# 0   David  27      UK            Python    85
# 1  Samuel  24  Canada    Data Structure    72
# 2   Terry  22   China  Machine Learning    89

# %% [markdown]
# Indexing by labels(i.e. using loc()) differs from indexing by integers (i.e. using iloc()). With loc(), both the start bound and the stop bound are inclusive. When using loc(), integers can be used, but the integers refer to the index label and not the position.

# %%
# let us do the slicing using old dataframe df

df1.iloc[0:2, 0:3]
# Out:
#   Student Age Country
# 0   David  27      UK
# 1  Samuel  24  Canada

# %%
df1.loc[2:3,'Age':'Course']
# Out:
#   Age Country            Course
# 2  22   China  Machine Learning
# 3  32     USA   Web Development
