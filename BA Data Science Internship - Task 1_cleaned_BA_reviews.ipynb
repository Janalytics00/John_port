# %% [markdown]
# <a href="https://colab.research.google.com/github/Janalytics00/John_port/blob/main/BA%20Data%20Science%20Internship%20-%20Task%201_cleaned_BA_reviews.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Data Cleaning**
#
# Now since we have extracted data from the website, it is not cleaned and ready to be analyzed yet. The reviews section will need to be cleaned for punctuations, spellings and other characters.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

#regex
import re

# %%
cwd = os.getcwd()

df = pd.read_csv(cwd+"/sample_data/BA_reviews (1).csv", index_col=0)

# %%
df.head()
# Out:
#                                              reviews  stars             date  \
# 0  ✅ Trip Verified |  Manchester to Copenhagen vi...    5.0     1st May 2024
# 1  ✅ Trip Verified |  I have never seen such disr...    6.0  30th April 2024
# 2  ✅ Trip Verified |  Paid for a 14 hour long fli...    1.0  27th April 2024
# 3  ✅ Trip Verified |  Very inconsiderate PA annou...    1.0  25th April 2024
# 4  ✅ Trip Verified |  Absolutely terrible, lost m...    1.0  22nd April 2024
#
#           country
# 0         Denmark
# 1  United Kingdom
# 2       Singapore
# 3  United Kingdom
# 4  United Kingdom

# %% [markdown]
# We will also create a column which mentions if the user is verified or not.

# %%
df['verified'] = df.reviews.str.contains("Trip Verified")
df['verified']
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 3395    False
# 3396    False
# 3397    False
# 3398    False
# 3399    False
# Name: verified, Length: 3400, dtype: bool

# %% [markdown]
# **Cleaning Reviews**
#
# We will extract the column of reviews into a separate dataframe and clean it for semantic analysis

# %%
#for lemmatization of words we will use nltk library
import nltk
nltk.download('stopwords')
import nltk
nltk.download('wordnet')
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
lemma = WordNetLemmatizer()


reviews_data = df.reviews.str.strip("✅ Trip Verified |")

#create an empty list to collect cleaned data corpus
corpus =[]

#loop through each review, remove punctuations, small case it, join it and add it to corpus
for rev in reviews_data:
    rev = re.sub('[^a-zA-Z]',' ', rev)
    rev = rev.lower()
    rev = rev.split()
    rev = [lemma.lemmatize(word) for word in rev if word not in set(stopwords.words("english"))]
    rev = " ".join(rev)
    corpus.append(rev)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...

# %%
# add the corpus to the original dataframe
df['corpus'] = corpus

# %%
df.head(20)
# Out:
#                                               reviews  stars       date  \
# 0   ✅ Trip Verified |  Manchester to Copenhagen vi...    5.0        NaT
# 1   ✅ Trip Verified |  I have never seen such disr...    6.0 2024-04-30
# 2   ✅ Trip Verified |  Paid for a 14 hour long fli...    1.0 2024-04-27
# 3   ✅ Trip Verified |  Very inconsiderate PA annou...    1.0 2024-04-25
# 4   ✅ Trip Verified |  Absolutely terrible, lost m...    1.0        NaT
# 5   ✅ Trip Verified |  We booked premium economy r...    1.0 2024-04-20
# 6   ✅ Trip Verified |  We chose Rotterdam and Lond...    1.0 2024-04-12
# 7   ✅ Trip Verified | The entire booking and ticke...    6.0 2024-04-10
# 8   Not Verified |   British Airways cancelled my ...    1.0 2024-04-10
# 9   Not Verified | I wanted to write this review s...    1.0 2024-04-07
# 10  ✅ Trip Verified |  Check in fast and friendly....   10.0        NaT
# 11  ✅ Trip Verified |  This is the first time I ha...    7.0        NaT
# 12  ✅ Trip Verified |  Flew business class from Do...    3.0        NaT
# 13  ✅ Trip Verified |  Starting off at Heathrow Te...    4.0 2024-03-28
# 14  Not Verified |  We have flown this route with ...    8.0 2024-03-28
# 15  ✅ Trip Verified | A last minute business trip ...    1.0 2024-03-26
# 16  ✅ Trip Verified |   Overall I would say disapp...    8.0 2024-03-26
# 17  Not Verified |  LHR to Delhi in Business. Exce...    5.0 2024-03-25
# 18  Not Verified |  Efficient and Smooth flight fr...   10.0 2024-03-25
# 19  ✅ Trip Verified | Was told we can not take han...    9.0 2024-03-25
#
#            country  verified  \
# 0          Denmark      True
# 1   United Kingdom      True
# 2        Singapore      True
# 3   United Kingdom      True
# 4   United Kingdom      True
# 5    United States      True
# 6      Netherlands      True
# 7    United States      True
# 8    United States     False
# 9    United States     False
# 10  United Kingdom      True
# 11  United Kingdom      True
# 12  United Kingdom      True
# 13  United Kingdom      True
# 14  United Kingdom     False
# 15  United Kingdom      True
# 16  United Kingdom      True
# 17  United Kingdom     False
# 18  United Kingdom     False
# 19  United Kingdom      True
#
#                                                corpus
# 0   manchester copenhagen via london th april airc...
# 1   never seen disrespect customer rd time month u...
# 2   paid hour long flight ticket includes use flig...
# 3   inconsiderate pa announcement made purser appe...
# 4   absolutely terrible lost luggage flight delive...
# 5   booked premium economy round trip phoenix zuri...
# 6   chose rotterdam london city airport convenienc...
# 7   entire booking ticketing experience stressful ...
# 8   verified british airway cancelled flight le ho...
# 9   verified wanted write review could give huge t...
# 10  check fast friendly security breeze lounge bus...
# 11  first time seen new club world suite seat comf...
# 12  flew business class doha london st march servi...
# 13  starting heathrow terminal check fairly easy f...
# 14  verified flown route easyjet regularly twenty ...
# 15  last minute business trip hnd route regularly ...
# 16  overall would say disappointing due ba status ...
# 17  verified lhr delhi business exceptional flight...
# 18  verified efficient smooth flight start finish ...
# 19  told take hand luggage onto plane overhead cab...

# %% [markdown]
# **Cleaning/Fromat date**

# %%
df.dtypes
# Out:
# reviews      object
# stars       float64
# date         object
# country      object
# verified       bool
# corpus       object
# dtype: object

# %%
#convert the date to datetime format


# Assuming df is your DataFrame and 'date' is the column containing dates
df['date'] = pd.to_datetime(df['date'], format='%dth %B %Y', errors='coerce')

# %%
df.date.head()
# Out:
# 0          NaT
# 1   2024-04-30
# 2   2024-04-27
# 3   2024-04-25
# 4          NaT
# Name: date, dtype: datetime64[ns]

# %% [markdown]
# Cleaning ratings with stars

# %%
#check for unique values
df.stars.unique()
# Out:
# array([ 5.,  6.,  1., 10.,  7.,  3.,  4.,  8.,  9.,  2., nan])

# %%
df.stars.value_counts()
# Out:
# stars
# 1.0     837
# 2.0     395
# 3.0     392
# 8.0     331
# 10.0    277
# 7.0     271
# 9.0     259
# 5.0     240
# 4.0     228
# 6.0     168
# Name: count, dtype: int64

# %% [markdown]
# There are 5 rows having values "None" in the ratings. We will drop all these 5 rows.

# %%
#drop the rows where the value of ratings is NaT
df.drop(df[df.stars == "NaT"].index, axis=0, inplace=True)

# %%
#drop the rows where the value of ratings is NaT
df.drop(df[df.date == "NaT"].index, axis=0, inplace=True)

# %%
df.tail(30)
# Out:
#                                                 reviews  stars       date  \
# 3370  First time with BA (a code share flight for JA...   10.0 2014-11-20
# 3371  Travelled to and from India recently in Club W...    7.0 2014-11-20
# 3372  BA16 Singapore to London. B777 World Traveller...    9.0 2014-11-20
# 3373  LHR to DXB on November 6 an overnight relative...    1.0 2014-11-20
# 3374  LHR-LCA in Club Europe. The First class lounge...    7.0 2014-11-20
# 3375  52b on upper deck to LAX and 51b back from LAX...    2.0 2014-11-20
# 3376  LHR – LAX Club World A380 return a week later ...    9.0 2014-11-20
# 3377  San Francisco to London Heathrow in August - a...    5.0 2014-11-20
# 3378  SFO-LHR-DXB and return DXB-LHR-DEN outbound in...    5.0 2014-11-20
# 3379  I travel to and from Singapore on BA in Club w...    NaN 2014-11-20
# 3380  Flew with my wife LHR-JNB BA055 on an A380 Oct...    8.0 2014-11-20
# 3381  London Heathrow to Zagreb return in economy. U...   10.0 2014-11-20
# 3382  LHR-MAD Club Europe A320 Seat 2A 15.25 hrs dep...   10.0 2014-11-20
# 3383  MIA-LHR-BKK round trip club world three 777 an...    8.0 2014-11-20
# 3384  Dallas Fort Worth Texas to London Heathrow BA ...    4.0 2014-11-20
# 3385  LHR-VIE in Club Europe on A320. Plane was an e...    3.0 2014-11-20
# 3386  Just flew to and from New York JFK with BA fli...    5.0 2014-11-17
# 3387  I had a very poor experience with BA from Jo'b...    8.0 2014-11-17
# 3388  Flew MCT to LHR on 1 Nov 14. Staff at Muscat w...    1.0 2014-11-17
# 3389  LAX/LHR. The flight started badly with the lou...    8.0 2014-11-17
# 3390  Kingston - London Gatwick in club world. Check...   10.0 2014-11-12
# 3391  LHR-JNB 15/10. I cannot understand why BA have...    6.0 2014-11-12
# 3392  Flew BA to Munich. Quick check-in good boardin...   10.0 2014-11-12
# 3393  Worst experience from Bangalore to Heathrow - ...    1.0 2014-11-12
# 3394  BA 83 from LHR to LAX first time on Airbus A38...   10.0 2014-11-12
# 3395  LPT to LHR and back found the planes new and i...    7.0 2014-11-12
# 3396  London Gatwick - Barbados in premium economy. ...    9.0 2014-11-12
# 3397  LHR-ZRH. A320 was used on this route. I was no...    9.0 2014-11-12
# 3398  I flew from MIA-LHR-DXB. The 747 like most of ...    6.0 2014-11-11
# 3399  Travelled from Gatwick to Orlando on the 24th ...    4.0 2014-11-06
#
#                    country  verified  \
# 3370             Australia     False
# 3371               Ireland     False
# 3372             Singapore     False
# 3373         United States     False
# 3374        United Kingdom     False
# 3375        United Kingdom     False
# 3376        United Kingdom     False
# 3377        United Kingdom     False
# 3378         United States     False
# 3379        United Kingdom     False
# 3380                France     False
# 3381        United Kingdom     False
# 3382        United Kingdom     False
# 3383         United States     False
# 3384        United Kingdom     False
# 3385             Australia     False
# 3386        United Kingdom     False
# 3387        United Kingdom     False
# 3388        United Kingdom     False
# 3389        United Kingdom     False
# 3390                 Spain     False
# 3391                France     False
# 3392        United Kingdom     False
# 3393         United States     False
# 3394         United States     False
# 3395              Portugal     False
# 3396                 Spain     False
# 3397         United States     False
# 3398  United Arab Emirates     False
# 3399        United Kingdom     False
#
#                                                  corpus
# 3370  first time ba code share flight jal travelled ...
# 3371  avelled india recently club world outbound hyd...
# 3372  ba singapore london b world traveller cabin on...
# 3373  lhr dxb november overnight relatively short fl...
# 3374  lhr lca club europe first class lounge fairly ...
# 3375  b upper deck lax b back lax lhr food flight ok...
# 3376  lhr lax club world return week later lax lhr f...
# 3377  san francisco london heathrow august appalling...
# 3378  sfo lhr dxb return dxb lhr den outbound premiu...
# 3379  travel singapore ba club world month first tim...
# 3380  flew wife lhr jnb ba october st back jnb lhr b...
# 3381  london heathrow zagreb return economy used ba ...
# 3382  lhr mad club europe seat hr departure newly re...
# 3383  mia lhr bkk round trip club world three one ch...
# 3384  dallas fort worth texas london heathrow ba th ...
# 3385  lhr vie club europe plane ex bmi aircraft stil...
# 3386  flew new york jfk ba flight great modern plane...
# 3387  poor experience ba jo burg london cancelled ke...
# 3388  flew mct lhr nov staff muscat excellent could ...
# 3389  lax lhr flight started badly lounge facility l...
# 3390  kingston london gatwick club world check fast ...
# 3391  lhr jnb cannot understand ba chosen seating ar...
# 3392  flew ba munich quick check good boarding sandw...
# 3393  worst experience bangalore heathrow delayed co...
# 3394  ba lhr lax first time airbus comfortable quiet...
# 3395  lpt lhr back found plane new good condition fa...
# 3396  london gatwick barbados premium economy saturd...
# 3397  lhr zrh used route expecting much since flight...
# 3398  flew mia lhr dxb like crew well passed sell da...
# 3399  avelled gatwick orlando th october ba disappoi...

# %%
df.stars.unique()
# Out:
# array([ 5.,  6.,  1., 10.,  7.,  3.,  4.,  8.,  9.,  2., nan])

# %% [markdown]
# check for null values

# %%
df.isnull().value_counts()
# Out:
# reviews  stars  date   country  verified  corpus
# False    False  False  False    False     False     2699
#                 True   False    False     False      698
#          True   False  False    False     False        2
#          False  False  True     False     False        1
# Name: count, dtype: int64

# %%
df.country.isnull().value_counts()
# Out:
# country
# False    3399
# True        1
# Name: count, dtype: int64

# %%
#drop the rows using index where the country value is null

df.dropna(inplace=True)

# %%
df.isnull().value_counts()
# Out:
# reviews  stars  date   country  verified  corpus
# False    False  False  False    False     False     2699
# Name: count, dtype: int64

# %%
df.head(10)
# Out:
#                                               reviews  stars       date  \
# 1   ✅ Trip Verified |  I have never seen such disr...    6.0 2024-04-30
# 2   ✅ Trip Verified |  Paid for a 14 hour long fli...    1.0 2024-04-27
# 3   ✅ Trip Verified |  Very inconsiderate PA annou...    1.0 2024-04-25
# 5   ✅ Trip Verified |  We booked premium economy r...    1.0 2024-04-20
# 6   ✅ Trip Verified |  We chose Rotterdam and Lond...    1.0 2024-04-12
# 7   ✅ Trip Verified | The entire booking and ticke...    6.0 2024-04-10
# 8   Not Verified |   British Airways cancelled my ...    1.0 2024-04-10
# 9   Not Verified | I wanted to write this review s...    1.0 2024-04-07
# 13  ✅ Trip Verified |  Starting off at Heathrow Te...    4.0 2024-03-28
# 14  Not Verified |  We have flown this route with ...    8.0 2024-03-28
#
#            country  verified  \
# 1   United Kingdom      True
# 2        Singapore      True
# 3   United Kingdom      True
# 5    United States      True
# 6      Netherlands      True
# 7    United States      True
# 8    United States     False
# 9    United States     False
# 13  United Kingdom      True
# 14  United Kingdom     False
#
#                                                corpus
# 1   never seen disrespect customer rd time month u...
# 2   paid hour long flight ticket includes use flig...
# 3   inconsiderate pa announcement made purser appe...
# 5   booked premium economy round trip phoenix zuri...
# 6   chose rotterdam london city airport convenienc...
# 7   entire booking ticketing experience stressful ...
# 8   verified british airway cancelled flight le ho...
# 9   verified wanted write review could give huge t...
# 13  starting heathrow terminal check fairly easy f...
# 14  verified flown route easyjet regularly twenty ...

# %%
df.shape
# Out:
# (2699, 6)

# %%
#resetting the index
df.reset_index(drop=True)
# Out:
#                                                 reviews  stars       date  \
# 0     ✅ Trip Verified |  I have never seen such disr...    6.0 2024-04-30
# 1     ✅ Trip Verified |  Paid for a 14 hour long fli...    1.0 2024-04-27
# 2     ✅ Trip Verified |  Very inconsiderate PA annou...    1.0 2024-04-25
# 3     ✅ Trip Verified |  We booked premium economy r...    1.0 2024-04-20
# 4     ✅ Trip Verified |  We chose Rotterdam and Lond...    1.0 2024-04-12
# ...                                                 ...    ...        ...
# 2694  LPT to LHR and back found the planes new and i...    7.0 2014-11-12
# 2695  London Gatwick - Barbados in premium economy. ...    9.0 2014-11-12
# 2696  LHR-ZRH. A320 was used on this route. I was no...    9.0 2014-11-12
# 2697  I flew from MIA-LHR-DXB. The 747 like most of ...    6.0 2014-11-11
# 2698  Travelled from Gatwick to Orlando on the 24th ...    4.0 2014-11-06
#
#                    country  verified  \
# 0           United Kingdom      True
# 1                Singapore      True
# 2           United Kingdom      True
# 3            United States      True
# 4              Netherlands      True
# ...                    ...       ...
# 2694              Portugal     False
# 2695                 Spain     False
# 2696         United States     False
# 2697  United Arab Emirates     False
# 2698        United Kingdom     False
#
#                                                  corpus
# 0     never seen disrespect customer rd time month u...
# 1     paid hour long flight ticket includes use flig...
# 2     inconsiderate pa announcement made purser appe...
# 3     booked premium economy round trip phoenix zuri...
# 4     chose rotterdam london city airport convenienc...
# ...                                                 ...
# 2694  lpt lhr back found plane new good condition fa...
# 2695  london gatwick barbados premium economy saturd...
# 2696  lhr zrh used route expecting much since flight...
# 2697  flew mia lhr dxb like crew well passed sell da...
# 2698  avelled gatwick orlando th october ba disappoi...
#
# [2699 rows x 6 columns]

# %% [markdown]
# Now our data is all cleaned and ready for data visualization and data analysis.

# %%
# export the cleaned data
df.to_csv(cwd + "/cleaned_BA_reviews.csv")
